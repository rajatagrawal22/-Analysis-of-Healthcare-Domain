# %%
import json
from pymongo import MongoClient
import xml.etree.ElementTree as etr

# %%
def file_parser(path):
    try:
        flightparse=etr.parse(path)
        flight=flightparse.getroot()
        return flight
    except FileNotFoundError:
        print("Given File not available".format(path))
    except IOError:
        print("Unable to read from given file".format(path))
    finally:
        print("File parsing complete")
        
path=r'C:\Users\Rajat Agrawal\Desktop\MSCCAD\CA2\data\covid.xml'
covid=file_parser(path)
# Out:
# File parsing complete

# %%
for i in covid.iter('neighnor'):
    print(neighnor.attrib)

# %%
covid.findall("row")
# Out:
# [<Element 'row' at 0x0000028317029E50>]

# %%
covid
# Out:
# <Element 'response' at 0x0000028317029E00>

# %%
covid.attrib
# Out:
# {}

# %%
final_list=[]
counter=0
for obj in covid.findall('row/'):
    try:
        lab_report_date=obj.find('lab_report_date').text
        cases_total=obj.find('cases_total').text
        deaths_total=obj.find('deaths_total').text
        hospitalizations_total=obj.find('hospitalizations_total').text
        cases_age_0_17=obj.find('cases_age_0_17').text
        cases_age_18_29=obj.find('cases_age_18_29').text
        cases_age_30_39=obj.find('cases_age_30_39').text
        cases_age_40_49=obj.find('cases_age_40_49').text
        
        cases_age_50_59=obj.find('cases_age_50_59').text
        cases_age_60_69=obj.find('cases_age_60_69').text
        cases_age_70_79=obj.find('cases_age_70_79').text
        cases_age_80_=obj.find('cases_age_80_').text
        cases_age_unknown=obj.find('cases_age_unknown').text
        
        cases_female=obj.find('cases_female').text
        cases_male=obj.find('cases_male').text
        cases_unknown_gender=obj.find('cases_unknown_gender').text
        
        cases_latinx=obj.find('cases_latinx').text
        cases_asian_non_latinx=obj.find('cases_asian_non_latinx').text
        cases_black_non_latinx=obj.find('cases_black_non_latinx').text
        
        cases_white_non_latinx=obj.find('cases_white_non_latinx').text
        cases_other_non_latinx=obj.find('cases_other_non_latinx').text
        cases_unknown_race_eth=obj.find('cases_unknown_race_eth').text
        deaths_0_17_yrs=obj.find('deaths_0_17_yrs').text
        deaths_18_29_yrs=obj.find('deaths_18_29_yrs').text
    
        deaths_30_39_yrs=obj.find('deaths_30_39_yrs').text
        deaths_40_49_yrs=obj.find('deaths_40_49_yrs').text
        deaths_50_59_yrs=obj.find('deaths_50_59_yrs').text
        deaths_60_69_yrs=obj.find('deaths_60_69_yrs').text
        deaths_70_79_yrs=obj.find('deaths_70_79_yrs').text

        deaths_80_yrs=obj.find('deaths_80_yrs').text
        deaths_unknown_age=obj.find('deaths_unknown_age').text
        deaths_female=obj.find('deaths_female').text
        deaths_male=obj.find('deaths_male').text
        deaths_unknown_gender=obj.find('deaths_unknown_gender').text
        
        deaths_latinx=obj.find('deaths_latinx').text
        deaths_asian_non_latinx=obj.find('deaths_asian_non_latinx').text
        deaths_black_non_latinx=obj.find('deaths_black_non_latinx').text
        deaths_white_non_latinx=obj.find('deaths_white_non_latinx').text
        deaths_other_non_latinx=obj.find('deaths_other_non_latinx').text
        
        deaths_unknown_race_eth=obj.find('deaths_unknown_race_eth').text
        hospitalizations_age_0_17=obj.find('hospitalizations_age_0_17').text
        hospitalizations_age_18_29=obj.find('hospitalizations_age_18_29').text
        hospitalizations_age_30_39=obj.find('hospitalizations_age_30_39').text
        hospitalizations_age_40_49=obj.find('hospitalizations_age_40_49').text

        hospitalizations_age_50_59=obj.find('hospitalizations_age_50_59').text
        hospitalizations_age_60_69=obj.find('hospitalizations_age_60_69').text
        hospitalizations_age_70_79=obj.find('hospitalizations_age_70_79').text
        hospitalizations_age_80_=obj.find('hospitalizations_age_80_').text
        hospitalizations_age_unknown=obj.find('hospitalizations_age_unknown').text
        
        hospitalizations_female=obj.find('hospitalizations_female').text
        hospitalizations_male=obj.find('hospitalizations_male').text
        hospitalizations_unknown_gender=obj.find('hospitalizations_unknown_gender').text
        hospitalizations_latinx=obj.find('hospitalizations_latinx').text
        hospitalizations_asian_non_latinx=obj.find('hospitalizations_asian_non_latinx').text
                
        hospitalizations_black_non_latinx=obj.find('hospitalizations_black_non_latinx').text
        hospitalizations_white_non_latinx=obj.find('hospitalizations_white_non_latinx').text
        hospitalizations_other_race_non_latinx=obj.find('hospitalizations_other_race_non_latinx').text
        hospitalizations_unknown_race_ethnicity=obj.find('hospitalizations_unknown_race_ethnicity').text
        
        final_list.append({"lab_report_date":lab_report_date,
                         "cases_total" : cases_total,
                         "deaths_total":deaths_total,
                         "hospitalizations_total":hospitalizations_total,
                           
                         "cases_age_0_17":cases_age_0_17,
                         "cases_age_18_29": cases_age_18_29,
                         "cases_age_30_39": cases_age_30_39,
                         "cases_age_40_49": cases_age_40_49,
                         "cases_age_50_59": cases_age_50_59,
                         "cases_age_60_69": cases_age_60_69,
                           "cases_age_70_79": cases_age_70_79,
                           "cases_age_80_":cases_age_80_,
                           "cases_age_unknown":cases_age_unknown,
                           "cases_female":cases_female,
                           "cases_male":cases_male,
                           "cases_unknown_gender":cases_unknown_gender,
                           
                           "cases_latinx":cases_latinx,
                           "cases_asian_non_latinx":cases_asian_non_latinx,
                           "cases_black_non_latinx":cases_black_non_latinx,
                           "cases_white_non_latinx":cases_white_non_latinx,    
                         "cases_other_non_latinx" : cases_other_non_latinx,
                           
                         "cases_unknown_race_eth":cases_unknown_race_eth,
                         "deaths_0_17_yrs":deaths_0_17_yrs,
                         "deaths_18_29_yrs":deaths_18_29_yrs,
                         "deaths_30_39_yrs": deaths_30_39_yrs,
                         "deaths_40_49_yrs": deaths_40_49_yrs,
                         "deaths_50_59_yrs": deaths_50_59_yrs,
                         "deaths_60_69_yrs": deaths_60_69_yrs,
                         "deaths_70_79_yrs": deaths_70_79_yrs,
                           "deaths_80_yrs": deaths_80_yrs,
                           
                           "deaths_unknown_age":deaths_unknown_age,
                           "deaths_female":deaths_female,
                           "deaths_male":deaths_male,
                           "deaths_unknown_gender":deaths_unknown_gender,
                           
                           "deaths_latinx":deaths_latinx,
                           "deaths_asian_non_latinx":deaths_asian_non_latinx,
                           "deaths_black_non_latinx":deaths_black_non_latinx,
                           "deaths_white_non_latinx":deaths_white_non_latinx,
                           "deaths_other_non_latinx":deaths_other_non_latinx,
                           
                           "deaths_unknown_race_eth":deaths_unknown_race_eth,
                         "hospitalizations_age_0_17" : hospitalizations_age_0_17,
                         "hospitalizations_age_18_29":hospitalizations_age_18_29,
                         "hospitalizations_age_30_39":hospitalizations_age_30_39,
                         "hospitalizations_age_40_49":hospitalizations_age_40_49,
                         "hospitalizations_age_50_59": hospitalizations_age_50_59,
                         "hospitalizations_age_60_69": hospitalizations_age_60_69,
                         "hospitalizations_age_70_79": hospitalizations_age_70_79,
                         "hospitalizations_age_80_": hospitalizations_age_80_,
                         "hospitalizations_age_unknown": hospitalizations_age_unknown,
                           "hospitalizations_female": hospitalizations_female,
                           
                           "hospitalizations_male":hospitalizations_male,
                           "hospitalizations_unknown_gender":hospitalizations_unknown_gender,
                           "hospitalizations_latinx":hospitalizations_latinx,
                           "hospitalizations_asian_non_latinx":hospitalizations_asian_non_latinx,
                           "hospitalizations_black_non_latinx":hospitalizations_black_non_latinx,
                           "hospitalizations_white_non_latinx":hospitalizations_white_non_latinx,
                           "hospitalizations_other_race_non_latinx":hospitalizations_other_race_non_latinx,
                           "hospitalizations_unknown_race_ethnicity":hospitalizations_unknown_race_ethnicity
                          })
    except Exception as e:
            print(e)
            pass
    counter=counter+1
    print("------------------------------------------------")
# Out:
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ...

# %%
counter
# Out:
# 1022

# %%
final_list
# Out:
# [{'lab_report_date': '2021-05-17T00:00:00',
#   'cases_total': '346',
#   'deaths_total': '7',
#   'hospitalizations_total': '50',
#   'cases_age_0_17': '58',
#   'cases_age_18_29': '84',
#   'cases_age_30_39': '74',
#   'cases_age_40_49': '44',
#   'cases_age_50_59': '38',
#   'cases_age_60_69': '33',
#   'cases_age_70_79': '8',
#   'cases_age_80_': '7',
#   'cases_age_unknown': '0',
#   'cases_female': '197',
#   'cases_male': '149',
#   'cases_unknown_gender': '0',
#   'cases_latinx': '72',
#   'cases_asian_non_latinx': '12',
#   'cases_black_non_latinx': '158',
#   'cases_white_non_latinx': '55',
#   'cases_other_non_latinx': '14',
#   'cases_unknown_race_eth': '35',
#   'deaths_0_17_yrs': '0',
#   'deaths_18_29_yrs': '0',
#   'deaths_30_39_yrs': '0',
#   'deaths_40_49_yrs': '0',
#   'deaths_50_59_yrs': '1',
#   'deaths_60_69_yrs': '1',
#   'deaths_70_79_yrs': '3',
#   'deaths_80_yrs': '2',
#   'deaths_unknown_age': '0',
#   'deaths_female': '3',
#   'deaths_male': '4',
# ...

# %%
# Making Connection
client  = MongoClient("mongodb://localhost:27017/")
  
# database
mydb  = client["DAP"]
  
# Created or Switched to collection
# names: GeeksForGeeks
mycol  = mydb["COVID"]
mydb
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'DAP')

# %%
mycol
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'DAP'), 'COVID')

# %%
mycol.insert_many(final_list)
