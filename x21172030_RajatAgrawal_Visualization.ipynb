# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %%
#establishing the connection
conn = psycopg2.connect(
   database="dap_new", user='postgres', password='rajat@123', host='127.0.0.1', port= '5432'
)
conn.autocommit = True

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM public.covid;") #Execute the query;

# %%
print(cursor)
# Out:
# <cursor object at 0x000002484F1EBE40; closed: 0>

# %%
# cursor.fetchall()
column_names=['_id', 'lab_report_date', 'cases_total', 'deaths_total',
       'hospitalizations_total', 'cases_age_0_17', 'cases_age_18_29',
       'cases_age_30_39', 'cases_age_40_49', 'cases_age_50_59',
       'cases_age_60_69', 'cases_age_70_79', 'cases_age_80_',
       'cases_age_unknown', 'cases_female', 'cases_male',
       'cases_unknown_gender', 'cases_latinx', 'cases_asian_non_latinx',
       'cases_black_non_latinx', 'cases_white_non_latinx',
       'cases_other_non_latinx', 'cases_unknown_race_eth', 'deaths_0_17_yrs',
       'deaths_18_29_yrs', 'deaths_30_39_yrs', 'deaths_40_49_yrs',
       'deaths_50_59_yrs', 'deaths_60_69_yrs', 'deaths_70_79_yrs',
       'deaths_80_yrs', 'deaths_unknown_age', 'deaths_female', 'deaths_male',
       'deaths_unknown_gender', 'deaths_latinx', 'deaths_asian_non_latinx',
       'deaths_black_non_latinx', 'deaths_white_non_latinx',
       'deaths_other_non_latinx', 'deaths_unknown_race_eth',
       'hospitalizations_age_0_17', 'hospitalizations_age_18_29',
       'hospitalizations_age_30_39', 'hospitalizations_age_40_49',
       'hospitalizations_age_50_59', 'hospitalizations_age_60_69',
       'hospitalizations_age_70_79', 'hospitalizations_age_80_',
       'hospitalizations_age_unknown', 'hospitalizations_female',
       'hospitalizations_male', 'hospitalizations_unknown_gender',
       'hospitalizations_latinx', 'hospitalizations_asian_non_latinx',
       'hospitalizations_black_non_latinx',
       'hospitalizations_white_non_latinx',
       'hospitalizations_other_race_non_latinx',
       'hospitalizations_unknown_race_ethnicity']

# %%
covid_df=pd.DataFrame(cursor.fetchall(),columns=column_names)
covid_df
# Out:
#                            _id  \
# 0     639e70234a7c9e896691c319
# 1     639e70234a7c9e896691c31a
# 2     639e70234a7c9e896691c31b
# 3     639e70234a7c9e896691c31c
# 4     639e70234a7c9e896691c31d
# ...                        ...
# 1011  639e70234a7c9e896691c70c
# 1012  639e70234a7c9e896691c70d
# 1013  639e70234a7c9e896691c70e
# 1014  639e70234a7c9e896691c70f
# 1015  639e70234a7c9e896691c710
#
#                                         lab_report_date  \
# 0     2021-05-17T00:00:00                           ...
# 1     2020-11-23T00:00:00                           ...
# 2     2020-05-19T00:00:00                           ...
# 3     2022-04-08T00:00:00                           ...
# 4     2021-09-12T00:00:00                           ...
# ...                                                 ...
# 1011  2020-11-19T00:00:00                           ...
# 1012  2021-10-19T00:00:00                           ...
# 1013  2020-05-18T00:00:00                           ...
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 59 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   _id                                      1016 non-null   object
#  1   lab_report_date                          1016 non-null   object
#  2   cases_total                              1016 non-null   object
#  3   deaths_total                             1016 non-null   object
#  4   hospitalizations_total                   1016 non-null   object
#  5   cases_age_0_17                           1016 non-null   object
#  6   cases_age_18_29                          1016 non-null   object
#  7   cases_age_30_39                          1016 non-null   object
#  8   cases_age_40_49                          1016 non-null   object
#  9   cases_age_50_59                          1016 non-null   object
# ...

# %%
covid_df["cases_total"].unique()
# Out:
# array(['346                                               ',
#        '2374                                              ',
#        '888                                               ',
#        '397                                               ',
#        '266                                               ',
#        '184                                               ',
#        '931                                               ',
#        '1300                                              ',
#        '365                                               ',
#        '1226                                              ',
#        '235                                               ',
#        '206                                               ',
#        '245                                               ',
#        '1463                                              ',
#        '162                                               ',
# ...

# %%
covid_df["cases_total"]= covid_df["cases_total"].str.replace(" ", "")

# %%
# removing white space as data type is object
for i in covid_df.columns:
    covid_df[i]= covid_df[i].str.replace(" ", "")

# %%
covid_df["cases_total"].unique()
# Out:
# array(['346', '2374', '888', '397', '266', '184', '931', '1300', '365',
#        '1226', '235', '206', '245', '1463', '162', '368', '27', '46',
#        '219', '28', '530', '268', '281', '556', '379', '350', '363',
#        '225', '355', '2343', '288', '244', '964', '95', '3', '97', '722',
#        '3322', '356', '1156', '1384', '968', '327', '1016', '412', '745',
#        '130', '860', '31', '35', '675', '164', '352', '857', '72', '1294',
#        '248', '438', '358', '203', '218', '143', '120', '789', '337',
#        '814', '1215', '309', '21', '326', '0', '51', '3987', '915', '169',
#        '173', '442', '221', '1651', '742', '330', '1460', '170', '558',
#        '381', '318', '538', '801', '487', '971', '283', '574', '5', '955',
#        '282', '280', '750', '832', '49', '254', '106', '347', '592',
#        '680', '174', '201', '391', '1670', '579', '734', '32', '128',
#        '404', '682', '433', '167', '388', '1348', '178', '833', '436',
# ...

# %%
covid_df["cases_total"].astype(int)
# Out:
# 0        346
# 1       2374
# 2        888
# 3        397
# 4        266
#         ...
# 1011    2167
# 1012     321
# 1013     944
# 1014     402
# 1015     395
# Name: cases_total, Length: 1016, dtype: int32

# %%
covid_df
# Out:
#                            _id      lab_report_date cases_total deaths_total  \
# 0     639e70234a7c9e896691c319  2021-05-17T00:00:00         346            7
# 1     639e70234a7c9e896691c31a  2020-11-23T00:00:00        2374           19
# 2     639e70234a7c9e896691c31b  2020-05-19T00:00:00         888           27
# 3     639e70234a7c9e896691c31c  2022-04-08T00:00:00         397            0
# 4     639e70234a7c9e896691c31d  2021-09-12T00:00:00         266            5
# ...                        ...                  ...         ...          ...
# 1011  639e70234a7c9e896691c70c  2020-11-19T00:00:00        2167           17
# 1012  639e70234a7c9e896691c70d  2021-10-19T00:00:00         321            2
# 1013  639e70234a7c9e896691c70e  2020-05-18T00:00:00         944           33
# 1014  639e70234a7c9e896691c70f  2022-11-08T00:00:00         402            1
# 1015  639e70234a7c9e896691c710  2020-09-04T00:00:00         395            2
#
# ...

# %%
# covid_df.info()

# %%
# covid_df['lab_report_date'] = pd.to_datetime(covid_df['lab_report_date'], format = '%Y/%m/%d %H:%M')

# %%
covid_df
# Out:
#                            _id      lab_report_date cases_total deaths_total  \
# 0     639e70234a7c9e896691c319  2021-05-17T00:00:00         346            7
# 1     639e70234a7c9e896691c31a  2020-11-23T00:00:00        2374           19
# 2     639e70234a7c9e896691c31b  2020-05-19T00:00:00         888           27
# 3     639e70234a7c9e896691c31c  2022-04-08T00:00:00         397            0
# 4     639e70234a7c9e896691c31d  2021-09-12T00:00:00         266            5
# ...                        ...                  ...         ...          ...
# 1011  639e70234a7c9e896691c70c  2020-11-19T00:00:00        2167           17
# 1012  639e70234a7c9e896691c70d  2021-10-19T00:00:00         321            2
# 1013  639e70234a7c9e896691c70e  2020-05-18T00:00:00         944           33
# 1014  639e70234a7c9e896691c70f  2022-11-08T00:00:00         402            1
# 1015  639e70234a7c9e896691c710  2020-09-04T00:00:00         395            2
#
# ...

# %%
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
np.random.rand(10, 4)
# Out:
# array([[0.91924365, 0.09590813, 0.85995591, 0.55555912],
#        [0.71772695, 0.05055752, 0.79229861, 0.62371241],
#        [0.91682556, 0.59088485, 0.61085078, 0.74714158],
#        [0.10678497, 0.00868702, 0.757808  , 0.23043708],
#        [0.19815745, 0.91392119, 0.87938157, 0.0736712 ],
#        [0.81221667, 0.58185146, 0.39756665, 0.92324845],
#        [0.84667449, 0.82059462, 0.74692379, 0.5528347 ],
#        [0.56750397, 0.78524033, 0.72728654, 0.79600228],
#        [0.71582372, 0.15752501, 0.8377186 , 0.08328609],
#        [0.00159624, 0.65068332, 0.92485515, 0.38015515]])

# %%
df2 = pd.DataFrame(covid_df["cases_total"].astype(int).values, columns=["a"])

df2.plot.bar();

# %%
# cases,death,hospitalization---race,age,gender

# %%
covid_df.describe()
# Out:
#                              _id      lab_report_date cases_total  \
# count                       1016                 1016        1016
# unique                      1016                 1016         703
# top     639e70234a7c9e896691c319  2021-05-17T00:00:00         531
# freq                           1                    1           6
#
#        deaths_total hospitalizations_total cases_age_0_17 cases_age_18_29  \
# count          1016                   1016           1016            1016
# unique           52                    170            283             337
# top               1                     28             51              65
# freq            136                     37             15              12
#
#        cases_age_30_39 cases_age_40_49 cases_age_50_59  ...  \
# count             1016            1016            1016  ...
# unique             323             278             250  ...
# top                 69              53              49  ...
# ...

# %%
for i in covid_df.columns:
    try:
        covid_df[i]=covid_df[i].astype(int)
    except:
        pass

# %%
covid_df.describe()
# Out:
#         cases_total  deaths_total  hospitalizations_total  cases_age_0_17  \
# count   1016.000000   1016.000000             1016.000000     1016.000000
# mean     716.920276      7.838583               47.370079      116.429134
# std     1041.224831     10.195311               44.630821      213.935594
# min        0.000000      0.000000                1.000000        0.000000
# 25%      272.500000      1.000000               22.000000       33.000000
# 50%      441.000000      4.000000               32.000000       66.000000
# 75%      770.250000      9.000000               52.000000      116.000000
# max    10427.000000     58.000000              303.000000     2817.000000
#
#        cases_age_18_29  cases_age_30_39  cases_age_40_49  cases_age_50_59  \
# count      1016.000000      1016.000000      1016.000000      1016.000000
# mean        162.567913       141.971457       103.526575        85.212598
# std         250.057482       210.756667       146.860529       116.831242
# ...

# %%
# covid_df=pd.read_csv(r"C:\Users\Rajat Agrawal\Desktop\MSCCAD\CA2\data\COVID-19_Daily_Cases__Deaths__and_Hospitalizations (1).csv")

# %%
covid_df.head()
# Out:
#                         _id      lab_report_date  cases_total  deaths_total  \
# 0  639e70234a7c9e896691c319  2021-05-17T00:00:00          346             7
# 1  639e70234a7c9e896691c31a  2020-11-23T00:00:00         2374            19
# 2  639e70234a7c9e896691c31b  2020-05-19T00:00:00          888            27
# 3  639e70234a7c9e896691c31c  2022-04-08T00:00:00          397             0
# 4  639e70234a7c9e896691c31d  2021-09-12T00:00:00          266             5
#
#    hospitalizations_total  cases_age_0_17  cases_age_18_29  cases_age_30_39  \
# 0                      50              58               84               74
# 1                     127             274              542              492
# 2                      97              78              211              170
# 3                      14              59               99              100
# 4                      33              55               62               52
#
# ...

# %%
covid_df.columns
# Out:
# Index(['_id', 'lab_report_date', 'cases_total', 'deaths_total',
#        'hospitalizations_total', 'cases_age_0_17', 'cases_age_18_29',
#        'cases_age_30_39', 'cases_age_40_49', 'cases_age_50_59',
#        'cases_age_60_69', 'cases_age_70_79', 'cases_age_80_',
#        'cases_age_unknown', 'cases_female', 'cases_male',
#        'cases_unknown_gender', 'cases_latinx', 'cases_asian_non_latinx',
#        'cases_black_non_latinx', 'cases_white_non_latinx',
#        'cases_other_non_latinx', 'cases_unknown_race_eth', 'deaths_0_17_yrs',
#        'deaths_18_29_yrs', 'deaths_30_39_yrs', 'deaths_40_49_yrs',
#        'deaths_50_59_yrs', 'deaths_60_69_yrs', 'deaths_70_79_yrs',
#        'deaths_80_yrs', 'deaths_unknown_age', 'deaths_female', 'deaths_male',
#        'deaths_unknown_gender', 'deaths_latinx', 'deaths_asian_non_latinx',
#        'deaths_black_non_latinx', 'deaths_white_non_latinx',
#        'deaths_other_non_latinx', 'deaths_unknown_race_eth',
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 59 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   _id                                      1016 non-null   object
#  1   lab_report_date                          1016 non-null   object
#  2   cases_total                              1016 non-null   int32
#  3   deaths_total                             1016 non-null   int32
#  4   hospitalizations_total                   1016 non-null   int32
#  5   cases_age_0_17                           1016 non-null   int32
#  6   cases_age_18_29                          1016 non-null   int32
#  7   cases_age_30_39                          1016 non-null   int32
#  8   cases_age_40_49                          1016 non-null   int32
#  9   cases_age_50_59                          1016 non-null   int32
# ...

# %%
covid_df['Date'] = pd.to_datetime(covid_df['lab_report_date'], errors='coerce')
covid_df['Date']
# Out:
# 0      2021-05-17
# 1      2020-11-23
# 2      2020-05-19
# 3      2022-04-08
# 4      2021-09-12
#           ...
# 1011   2020-11-19
# 1012   2021-10-19
# 1013   2020-05-18
# 1014   2022-11-08
# 1015   2020-09-04
# Name: Date, Length: 1016, dtype: datetime64[ns]

# %%
covid_df['year'] = covid_df['Date'].dt.year
covid_df['month'] = covid_df['Date'].dt.month

# %%
covid_df["year"].value_counts()
# Out:
# 2021    365
# 2022    345
# 2020    306
# Name: year, dtype: int64

# %%
covid_df["month"].value_counts()
# Out:
# 5     93
# 10    93
# 8     93
# 3     93
# 7     93
# 11    90
# 4     90
# 9     90
# 6     90
# 12    73
# 1     62
# 2     56
# Name: month, dtype: int64

# %%
covid_df_2020=covid_df[covid_df["year"]==2020]
covid_df_2021=covid_df[covid_df["year"]==2021]
covid_df_2022=covid_df[covid_df["year"]==2022]
covid_df_2020.shape,covid_df_2021.shape,covid_df_2022.shape
# Out:
# ((306, 62), (365, 62), (345, 62))

# %%
covid_df_2020
# Out:
#                            _id      lab_report_date  cases_total  \
# 1     639e70234a7c9e896691c31a  2020-11-23T00:00:00         2374
# 2     639e70234a7c9e896691c31b  2020-05-19T00:00:00          888
# 7     639e70234a7c9e896691c320  2020-12-18T00:00:00         1300
# 8     639e70234a7c9e896691c321  2020-09-16T00:00:00          365
# 12    639e70234a7c9e896691c325  2020-06-24T00:00:00          245
# ...                        ...                  ...          ...
# 1004  639e70234a7c9e896691c705  2020-12-24T00:00:00          619
# 1005  639e70234a7c9e896691c706  2020-10-24T00:00:00          883
# 1011  639e70234a7c9e896691c70c  2020-11-19T00:00:00         2167
# 1013  639e70234a7c9e896691c70e  2020-05-18T00:00:00          944
# 1015  639e70234a7c9e896691c710  2020-09-04T00:00:00          395
#
#       deaths_total  hospitalizations_total  cases_age_0_17  cases_age_18_29  \
# 1               19                     127             274              542
# ...

# %%
lst1=[]
lst2=[]
lst_death=[]
for i in covid_df_2020["month"].unique():
    lst1.append(covid_df_2020[covid_df_2020["month"]==i]["cases_total"].mean())
    lst_death.append(covid_df_2020[covid_df_2020["month"]==i]["deaths_total"].mean())
    #print(df.shape)
    lst2.append(i)
df_2020=pd.DataFrame()
df_2020["Month"]=lst2
df_2020["Avg Cases"]=lst1
df_2020["Avg Deaths"]=lst_death
df_2020=df_2020.sort_values(by="Month")
df_2020
# Out:
#    Month    Avg Cases  Avg Deaths
# 7      3   142.387097    2.612903
# 8      4   719.066667   34.533333
# 1      5   688.000000   36.483871
# 4      6   210.200000   14.100000
# 5      7   266.967742    4.258065
# 6      8   327.903226    3.129032
# 3      9   312.266667    2.866667
# 9     10   870.903226    4.419355
# 0     11  1963.100000   16.333333
# 2     12  1340.193548   24.612903

# %%
lst1=[]
lst2=[]
lst_death=[]

for i in covid_df_2021["month"].unique():
    lst1.append(covid_df_2021[covid_df_2021["month"]==i]["cases_total"].mean())
    lst_death.append(covid_df_2021[covid_df_2021["month"]==i]["deaths_total"].mean())
    lst2.append(i)
df_2021=pd.DataFrame()
df_2021["Month"]=lst2
df_2021["Avg Cases"]=lst1
df_2021["Avg Deaths"]=lst_death
df_2021=df_2021.sort_values(by="Month")
df_2021
# Out:
#     Month    Avg Cases  Avg Deaths
# 8       1   854.580645   14.741935
# 10      2   336.535714    8.321429
# 4       3   411.774194    4.677419
# 7       4   608.900000    6.200000
# 0       5   253.387097    6.548387
# 2       6    52.966667    3.266667
# 9       7   155.258065    1.387097
# 3       8   481.290323    3.419355
# 1       9   420.900000    5.200000
# 11     10   311.935484    3.838710
# 5      11   588.833333    4.500000
# 6      12  3656.225806   11.935484

# %%
df_2021[0:3]
# Out:
#     Month   Avg Cases  Avg Deaths
# 8       1  854.580645   14.741935
# 10      2  336.535714    8.321429
# 4       3  411.774194    4.677419

# %%
lst1=[]
lst2=[]
lst_death=[]

for i in covid_df_2022["month"].unique():
    lst1.append(covid_df_2022[covid_df_2022["month"]==i]["cases_total"].mean())
    lst_death.append(covid_df_2022[covid_df_2022["month"]==i]["deaths_total"].mean())
    lst2.append(i)
df_2022=pd.DataFrame()
df_2022["Month"]=lst2
df_2022["Avg Cases"]=lst1
df_2022["Avg Deaths"]=lst_death
df_2022=df_2022.sort_values(by="Month")
df_2022
# Out:
#     Month    Avg Cases  Avg Deaths
# 8       1  2935.967742   25.354839
# 7       2   329.642857    8.107143
# 4       3   197.741935    1.580645
# 0       4   557.033333    0.533333
# 3       5  1102.967742    0.838710
# 11      6   839.800000    0.966667
# 9       7   794.870968    1.612903
# 2       8   659.677419    1.451613
# 5       9   402.700000    1.200000
# 1      10   345.935484    1.258065
# 6      11   450.100000    0.766667
# 10     12   565.909091    1.000000

# %%
import matplotlib.pyplot  as plt
import seaborn as sns
import numpy as np

# %%
# print(plt.__version__)

# %%
fig = plt.figure(figsize = (10, 5))
plt.plot(df_2020["Month"],df_2020["Avg Cases"].values,label = "2020",marker='o')
plt.plot(df_2021["Avg Cases"].values,label = "2021",marker='o')
plt.plot(df_2022["Avg Cases"].values,label = "2022",marker='o')

plt.xlabel("Month")
plt.ylabel("AVG Cases ")
plt.title("AVG Cases in years 2020,2021,2022")
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize = (10, 5))
plt.plot(df_2020["Month"],df_2020["Avg Deaths"].values,label = "2020",marker='o')
plt.plot(df_2021["Avg Deaths"].values,label = "2021",marker='o')
plt.plot(df_2022["Avg Deaths"].values,label = "2022",marker='o')

plt.xlabel("Month")
plt.ylabel("AVG Deaths ")
plt.title("AVG Deaths in years 2020,2021,2022")
plt.legend()
plt.show()

# %%
df_2022[["Avg Cases","Avg Deaths"]].plot(kind='bar')

# %%
import plotly.express as px

# # df = px.df.stocks()
# fig = px.line(df_2022, x='Month', y="Avg Cases")
# fig.show()

# %%
# fig = px.bar(df_2020, x=df_2020.Month, y='Avg Cases')
# fig.show()

# %%
# fig = px.bar(df_2021, x=df_2021.Month, y='Avg Cases')
# fig.show()

# %%
# fig = px.bar(df_2022, x=df_2022.Month, y='Avg Cases')
# fig.show()

# %%
covid_df.columns
# Out:
# Index(['_id', 'lab_report_date', 'cases_total', 'deaths_total',
#        'hospitalizations_total', 'cases_age_0_17', 'cases_age_18_29',
#        'cases_age_30_39', 'cases_age_40_49', 'cases_age_50_59',
#        'cases_age_60_69', 'cases_age_70_79', 'cases_age_80_',
#        'cases_age_unknown', 'cases_female', 'cases_male',
#        'cases_unknown_gender', 'cases_latinx', 'cases_asian_non_latinx',
#        'cases_black_non_latinx', 'cases_white_non_latinx',
#        'cases_other_non_latinx', 'cases_unknown_race_eth', 'deaths_0_17_yrs',
#        'deaths_18_29_yrs', 'deaths_30_39_yrs', 'deaths_40_49_yrs',
#        'deaths_50_59_yrs', 'deaths_60_69_yrs', 'deaths_70_79_yrs',
#        'deaths_80_yrs', 'deaths_unknown_age', 'deaths_female', 'deaths_male',
#        'deaths_unknown_gender', 'deaths_latinx', 'deaths_asian_non_latinx',
#        'deaths_black_non_latinx', 'deaths_white_non_latinx',
#        'deaths_other_non_latinx', 'deaths_unknown_race_eth',
# ...

# %% [markdown]
# # Hospitalization

# %%
mean_0_17=covid_df["hospitalizations_age_0_17"].mean()
mean_18_29=covid_df["hospitalizations_age_18_29"].mean()
mean_30_39=covid_df["hospitalizations_age_30_39"].mean()
mean_40_49=covid_df["hospitalizations_age_40_49"].mean()
mean_50_59=covid_df["hospitalizations_age_50_59"].mean()
mean_60_69=covid_df["hospitalizations_age_60_69"].mean()
mean_70_79=covid_df["hospitalizations_age_70_79"].mean()
mean_80=covid_df["hospitalizations_age_80_"].mean()

# %%
import seaborn
import matplotlib.pyplot as plt

# declaring data
data = [mean_0_17, mean_18_29, mean_30_39, mean_40_49, mean_50_59,mean_60_69, mean_70_79 ,mean_80]
keys = ['Age 0-17', 'Age 18-29', 'Age 30-39', 'Age 40-49', 'Age 50-59','Age 60-69','Age 70-79','Age 80+']
fig = plt.figure(figsize = (20, 10))
# declaring exploding pie
explode = [0, 0, 0, 0, 0,0.1,0,0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette('dark')
  
# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')
#plt.legend()
plt.title("Agewise distribution of Hospitalization ")
# displaying chart
plt.show()

# %% [markdown]
# # cases

# %%
mean_0_17=covid_df["cases_age_0_17"].mean()
mean_18_29=covid_df["cases_age_18_29"].mean()
mean_30_39=covid_df["cases_age_30_39"].mean()
mean_40_49=covid_df["cases_age_40_49"].mean()
mean_50_59=covid_df["cases_age_50_59"].mean()
mean_60_69=covid_df["cases_age_60_69"].mean()
mean_70_79=covid_df["cases_age_70_79"].mean()
mean_80=covid_df["cases_age_80_"].mean()

# %%
mean_0_17,mean_18_29,mean_30_39
# Out:
# (116.42913385826772, 162.56791338582678, 141.9714566929134)

# %%
import seaborn
import matplotlib.pyplot as plt

# declaring data
data = [mean_0_17, mean_18_29, mean_30_39, mean_40_49, mean_50_59,mean_60_69, mean_70_79 ,mean_80]
keys = ['Age 0-17', 'Age 18-29', 'Age 30-39', 'Age 40-49', 'Age 50-59','Age 60-69','Age 70-79','Age 80+']
fig = plt.figure(figsize = (20, 10))
# declaring exploding pie
explode = [0, 0.1, 0, 0, 0,0,0,0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette('dark')
  
# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')
#plt.legend()
plt.title("Agewise distribution of cases ")
# displaying chart
plt.show()

# %% [markdown]
# # deaths

# %%
# covid_df.columns

# %%
mean_0_17=covid_df["deaths_0_17_yrs"].mean()
mean_18_29=covid_df["deaths_18_29_yrs"].mean()
mean_30_39=covid_df["deaths_30_39_yrs"].mean()
mean_40_49=covid_df["deaths_40_49_yrs"].mean()
mean_50_59=covid_df["deaths_50_59_yrs"].mean()
mean_60_69=covid_df["deaths_60_69_yrs"].mean()
mean_70_79=covid_df["deaths_70_79_yrs"].mean()
mean_80=covid_df["deaths_80_yrs"].mean()

# %%
import seaborn
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (20, 10))

# declaring data
data = [mean_0_17, mean_18_29, mean_30_39, mean_40_49, mean_50_59,mean_60_69, mean_70_79 ,mean_80]
keys = ['Age 0-17', 'Age 18-29', 'Age 30-39', 'Age 40-49', 'Age 50-59','Age 60-69','Age 70-79','Age 80+']
#palette_color = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']
# declaring exploding pie
explode = [0, 0, 0, 0, 0,0,0.1,0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette('dark')
#print(palette_color)
# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%',shadow=True)
# plt.ylabel.set_visible(False)
plt.title("Agewise distribution of deaths ")
# displaying chart
plt.show()
